# %% [markdown]
# #🐍 TP 3 – Python peut te parler… et t’écouter !
#
# 🎯 Objectif : Créer des dialogues personnalisés avec input() et rendre les réponses plus dynamiques avec print().
#
# 👦👧 Niveau : débutant – suite logique des TP 1 et 2.

# %% [markdown]
# # ✅ Partie 1 – Les devinettes de Python

# %%
reponse = input("Quel est ton plat préféré ? ")

print("Hmm... " + reponse + "? J'aurais parié sur les pâtes !")
# Out:
# Quel est ton plat préféré ? Pizza
# Hmm... Pizza? J'aurais parié sur les pâtes !

# %% [markdown]
# 🎯 But : comprendre qu’on peut utiliser input() pour créer une conversation drôle ou piégeuse.
#
# 💡 Amuse-toi à créer ta propre devinette ou réaction surprenante !

# %% [markdown]
# # 🧙‍♀️ Partie 2 – Ton profil magique

# %%
nom = input("Quel est ton prénom de sorcier ? ")

objet = input("Quel objet magique utilises-tu ? ")

animal = input("Quel est ton animal de compagnie ? ")

print("🧙‍♂️ Le sorcier", nom, "utilise un", objet, "et voyage avec un", animal + " 🐾")

# %% [markdown]
# 🎯 But : construire une phrase complète et cohérente avec plusieurs input().
#
# 💡 Idée bonus : transforme ça en fiche d’identité magique

# %% [markdown]
# # 🧠 Partie 3 – Les erreurs que Python déteste
#
# **❌ Erreur classique 1 – Mélange de types**

# %%
age = input("Quel âge as-tu ? ")

print("Dans 10 ans, tu auras " + age + 10 + " ans.")

# %% [markdown]
# ❓ Que va-t-il se passer ?
#
# ➡ Python va râler ! Tu ne peux pas additionner du texte et un nombre.
#
# ✅ Correction :

# %%
age = input("Quel âge as-tu ? ")

print("Dans 10 ans, tu auras " + str(int(age) + 10) + " ans.")

# %% [markdown]
# **Explication :**
#
# 🔤 str() transforme un nombre en texte pour pouvoir l’afficher ou le coller dans une phrase.
#
# 🔢 int() transforme un texte (comme "12") en nombre pour pouvoir faire des calculs.
#
# 🔄 On utilise int() pour calculer, puis str() pour afficher le résultat dans une phrase.

# %% [markdown]
# **🧩 Résumé rigolo :**
#
# En Python, les textes et les nombres sont comme des briques LEGO de couleurs différentes.
#
# Tu ne peux pas les coller ensemble sans adaptateur !
#
# 🛠️ int() transforme une brique texte en brique nombre pour faire des calculs.
#
# 🧱 str() transforme une brique nombre en brique texte pour pouvoir l’assembler dans une phrase.

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# # 🏁 Partie 4 – À toi de créer ton mini-jeu 🎮
#
# 💡 Défi créatif : Invente un programme avec au moins :
#
# 3 questions avec input(),
#
# 1 phrase drôle ou surprenante en réponse,
#
# et 0 erreur 😄

# %%
#Complète ici

# %% [markdown]
# **🧙 Bravo !**
#
# Tu viens de découvrir comment Python peut :
#
# Te poser des questions,
#
# Créer des dialogues dynamiques,
#
#   fficher des réponses personnalisées.
