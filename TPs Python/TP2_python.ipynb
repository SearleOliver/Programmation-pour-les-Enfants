# %% [markdown]
# # 🐍 TP 2 – À la découverte des erreurs  !
#
# 🎯 Objectif : apprendre à repérer et corriger des erreurs en Python.
#
# 👦👧 Niveau : débutant – suite logique des TP 1

# %% [markdown]
# ## ✅ Partie 1 – Variable et affichage
# #### Objectif : Comprendre comment afficher une variable proprement.
# Dans cet exercice, tu vas :
#
# Retirer le # au début de la ligne (il sert à “commenter” le code, donc à le désactiver).
#
# Écrire ton âge à la place de ....

# %%
# age = ...  # Décommente cette ligne et entre ton âge (ex: 13)
print("Tu as " + age + " ans")
# Out:
# Traceback (most recent call last):
#   File "<basthon-input-14-e93c4ddd8a7f>", line 2, in <module>
#     print("Tu as " + age + " ans")
#           ~~~~~~~~~^~~~~
# TypeError: can only concatenate str (not "ellipsis") to str

# %% [markdown]
# ❌ Ce code provoque une erreur ❗
# Pourquoi ? Parce qu'on essaye de coller une chaîne de caractères ("Tu as ") avec un nombre entier (age). Et Python n'aime pas qu'on mélange ces deux-là directement !
#
# ✅ Correction :
#
# Voici la bonne façon de faire :

# %%
# age = ...  #Décommente cette ligne et entre ton âge (ex: 13)
print("Tu as ", age, " ans")
# Out:
# Tu as  Ellipsis  ans

# %% [markdown]
# Ou encore de cette façon :

# %%
# age = ...  #Décommente cette ligne et entre ton âge (ex: 13)
print("Tu as " + str(age) +" ans")
# Out:
# Tu as Ellipsis ans

# %% [markdown]
# ## ✅ Partie 2 – Les conversions avec int( )
# En Python, la fonction int() permet de convertir un nombre ou une donnée en entier. Mais attention, elle ne marche pas dans tous les cas...

# %% [markdown]
# Test 1: convertir un nombre décimal positif

# %%
x = int(3.9)
print(x)
# Out:
# 3

# %% [markdown]
#  Remarque : Même si 3.9 est proche de 4, int() enlève tout ce qu’il y a après la virgule, sans arrondir. On obtient juste la partie entière.

# %% [markdown]
# Test 2: convertir un nombre décimal negatif

# %%
x = int(-3.9)
print(x)
# Out:
# -3

# %% [markdown]
# ![nombres-relatifs-negatifs.jpg](attachment:nombres-relatifs-negatifs.jpg)

# %% [markdown]
# ❌ Test 3 : convertir une chaine de lettres

# %%
x=int("abc")
print(x)
# Out:
# Traceback (most recent call last):
#   File "<basthon-input-4-9d83e4379537>", line 1, in <module>
#     x=int("abc")
#       ^^^^^^^^^^
# ValueError: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# ⚠️  Ici , Pyhton ne peut pas transformer "abc" en un nombre. Il ne reconnait pas ces lettres comme un nombre valide.

# %% [markdown]
# ## ✅ Partie 3 – La division par zéro
# En maths, tu sais sûrement qu’on ne peut pas diviser par zéro. Eh bien, Python non plus ! Si tu essaies, il te le fera savoir… avec une erreur ⛔️!

# %% [markdown]
# Essaye d'éxecuter ce code, que se passe t-il🤔

# %%
x=10/0
print(x)
# Out:
# Traceback (most recent call last):
#   File "<basthon-input-1-531c6574f0d2>", line 1, in <module>
#     x=10/0
#       ~~^~
# ZeroDivisionError: division by zero

# %% [markdown]
# 🚫 Que s’est-il passé ?
# Python a vu qu’on essayait de faire une division impossible. Comme il ne peut pas continuer, il s’arrête et affiche une erreur appelée ZeroDivisionError.

# %% [markdown]
# À toi de corriger !
# Teste une version sans erreur en changeant le dénominateur (le 0) pour un autre nombre :

# %%
x=...
print(x)
# Out:
# Ellipsis

# %% [markdown]
# ### 🧮 Petit rappel sur les symboles en Python

# %% [markdown]
# L’étoile * sert à multiplier.
#
# Le slash / sert à diviser.
#
# Le moins - sert à soustraire (comme en maths).

# %% [markdown]
#  ## ✅ Partie 4 – À toi d’écrire une opération en Python

# %% [markdown]
# Regarde bien l’image ci-dessous ,Puis écris en code Python l’opération mathématique que tu vois.

# %% [markdown]
# ![corrige.png](attachment:corrige.png)

# %%
#Écris ici ton calcul en Python

# %% [markdown]
#  🤔 Que s’est-il passé ?
