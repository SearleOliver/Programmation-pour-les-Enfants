# %% [markdown]
# # 🐍 TP – Les Bases de Python (Variables & Conditions)
#
# ---
#
# ## 👋 Bienvenue !
#
# Dans ce TP, tu vas découvrir les **bases de Python** 🐍
# C’est ici que tout commence : afficher du texte, utiliser des variables, et prendre des décisions avec ton programme !

# %% [markdown]
# ### ⏱️ Durée : ~45 minutes
#
# | 🟢 Partie | 📖 Contenu | ⏱️ Temps |
# |-----------|-----------|----------|
# | **Partie 1** | Afficher et variables | 10 min |
# | **Partie 2** | Calculs | 10 min |
# | **Partie 3** | Conditions (`if`) | 10 min |
# | **🎮 Défi final** | Mini-jeu : détective des nombres | 15 min |

# %% [markdown]
# ### 🗺️ Comment utiliser ce notebook ?
#
# 1. Lis chaque cellule
# 2. Exécute ▶️ (`Ctrl+Entrée`)
# 3. Complète les exercices (`# ✏️ TON CODE ICI`)
# 4. Amuse-toi ! 🎉

# %% [markdown]
# # 🟢 PARTIE 1 – Afficher et variables

# %% [markdown]
# ## 📖 Afficher du texte

# %% [markdown]
# Pour afficher quelque chose en Python, on utilise :

# %%
print("👋 Bonjour !")
print("Bienvenue en Python 🐍")
# Out:
# 👋 Bonjour !
# Bienvenue en Python 🐍

# %% [markdown]
# ## 📖 Les variables

# %% [markdown]
# Une variable, c’est une boîte 📦 où on stocke une valeur.

# %%
prenom = "Lucas"
age = 13

print("Je m'appelle", prenom)
print("J'ai", age, "ans")

# %% [markdown]
# ### ✏️ Exercice 1 – Ta présentation

# %% [markdown]
# Crée des variables :
#
# - prenom
# - age
#
# Puis affiche :
# 👋 Je m'appelle [prenom] et j'ai [age] ans

# %%
# ✏️ TON CODE ICI

# %% [markdown]
# ### ✏️ Exercice 2 – Emoji fun 🎉

# %% [markdown]
# Affiche : 🚀 Python c'est génial !

# %%
# ✏️ TON CODE ICI

# %% [markdown]
# # 🟡 PARTIE 2 – Les calculs

# %% [markdown]
# ## 📖 Les opérations (+, -, *, /)

# %% [markdown]
# | Symbole | Signification  |
# | ------- | -------------- |
# | `+`     | addition       |
# | `-`     | soustraction   |
# | `*`     | multiplication |
# | `/`     | division       |
#
# Exemple :

# %%
a = 10
b = 5

print('Addition :', a + b)
print('Multiplication :', a * b)

# %% [markdown]
# ### ✏️ Exercice 3 – Calcul simple

# %% [markdown]
# Crée deux variables a et b
#
# Affiche :
#
# - leur somme
# - leur produit

# %%
# ✏️ TON CODE ICI

# %% [markdown]
# ### ✏️ Exercice 4 – Aire d’un rectangle 📐

# %% [markdown]
# Crée :
#
# - longueur
# - largeur
#
# Puis affiche :
#
# Aire = ...
#
# 💡 Aire = longueur * largeur

# %%
# ✏️ TON CODE ICI

# %% [markdown]
# # 🔴 PARTIE 3 – Conditions (if)

# %%
nombre = 7

if nombre % 2 == 0:
    print('Pair')
else:
    print('Impair')

# %% [markdown]
# ### ✏️ Exercice 5 – Pair ou impair

# %%
# ✏️ TON CODE ICI

# %% [markdown]
# ### ✏️ Exercice 6 – Comparaison

# %%
# ✏️ TON CODE ICI

# %% [markdown]
# # 🎮 DÉFI FINAL – Détective des nombres 🕵️

# %%
# ✏️ TON CODE ICI

# %% [markdown]
# # 🏆 Félicitations !
#
# Tu sais maintenant utiliser :
# - print()
# - variables
# - calculs
# - conditions
