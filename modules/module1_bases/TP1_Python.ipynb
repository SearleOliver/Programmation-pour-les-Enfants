# %% [markdown]
# # 🐍 TP Python avec Basthon – Je découvre la programmation
#
# Bienvenue dans ton tout premier TP Python ! On va apprendre à faire parler l'ordinateur, à écrire un programme simple et à comprendre les erreurs. Prêt(e) ? C’est parti ! 🎉

# %% [markdown]
# ## ✅ Partie 1 – Hello world 🌍
#
# Voici le tout premier programme que presque tous les programmeurs écrivent un jour. Il sert à dire bonjour au monde !

# %%
print("Hello world!")

# %% [markdown]
# Clique sur ▶️ pour voir ce que ça affiche.
#
# `print()` sert à dire à Python d'afficher quelque chose à l'écran. Les guillemets `" "` servent à entourer le texte.

# %% [markdown]
# # ✏️ Tu peux maintenant écrire ce que tu veux
# Essaie de modifier la phrase ci-dessous pour qu’elle dise ce que tu veux : une blague, une phrase drôle, une citation, ce que tu aimes… C’est toi le chef ! 👩‍💻👨‍💻
#
# Amuse-toi à changer le texte entre les guillemets :

# %%
print("Remplace par la phrase de ton choix!")
# Out:
# Remplace par la phrase de ton choix!

# %% [markdown]
# Par exemple:

# %%
print("Pourquoi pas un jour créer mon propre jeu vidéo ? ")

# %% [markdown]
# ## 😊 Partie 2 – Je parle de moi
#
# Maintenant, on va faire dire à l’ordinateur une phrase qui parle de toi.

# %%
print("Bonjour, je m'appelle Diego et j'ai 12 ans.")
# Out:
# Bonjour, je m'appelle Diego et j'ai 12 ans.

# %% [markdown]
# Remplace `Diego` par **ton prénom**, et `12` par **ton âge**. Clique sur ▶️ pour voir le résultat.

# %% [markdown]
# ## 🧠 Partie 3 – Les erreurs
#
# Quand on code, on peut faire des erreurs. Ce n’est pas grave, c’est normal ! Il y a deux types d’erreurs :

# %% [markdown]
# ### ❌ Erreur de syntaxe (quand on oublie un bout de code)
#
# Essaie ce code (il contient une erreur) :

# %%
print("Bonjour)

# %% [markdown]
# Python va afficher une erreur rouge, car il manque un guillemet de fin. Corrige-le !

# %% [markdown]
# ### 🤔 Erreur de sens (quand la phrase est bizarre)
#
# Le programme marche, mais il dit quelque chose qui n’a pas de sens :

# %%
print("Bonjour, je m'appelle 13 et j'ai Maria ans.")

# %% [markdown]
# Corrige la phrase pour qu’elle ait du sens. Par exemple :

# %%
print("Bonjour, je m'appelle Maria et j'ai 13 ans.")

# %% [markdown]
# ## 🎁 Bonus – L’ordinateur te pose des questions !
#
# Voici un programme plus interactif. Il demande ton prénom et ton âge, puis il te répond.

# %%
prenom = input("Quel est ton prénom ? ")
age = input("Quel âge as-tu ? ")
print("Bonjour", prenom, "tu as", age, "ans.")
# Out:
# Quel est ton prénom ? maria
# Quel âge as-tu ? 12
# Bonjour maria tu as 12 ans.

# %% [markdown]
# Essaie-le et amuse-toi à changer les questions ! 🎉

# %% [markdown]
# ---
# ## 👏 Bravo !
#
# Tu viens d’écrire ton premier programme Python, de découvrir comment l’ordinateur lit ce qu’on écrit, et de comprendre les erreurs. Tu es officiellement un.e jeune programmeur.se ! 🚀
